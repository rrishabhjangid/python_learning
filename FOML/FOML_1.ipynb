# %%
import matplotlib.pyplot as plt

import numpy as np
 
def plot_lines(M):
 
    x_1 = np.linspace(-10, 10, 100)
    x_2_line_1 = (M[0,2] - M[0,0] * x_1) / M[0,1]
    x_2_line_2 = (M[1,2] - M[1,0] * x_1) / M[1,1]
 
    _, ax = plt.subplots(figsize=(10, 10))
 
    ax.plot(
        x_1, x_2_line_1,
        linewidth=2,
        color='#0075ff',
        label=f'$x_2={-M[0,0]/M[0,1]:.2f}x_1 + {M[0,2]/M[0,1]:.2f}$'
    )
 
    ax.plot(
        x_1, x_2_line_2,
        linewidth=2,
        color='#ff7300',
        label=f'$x_2={-M[1,0]/M[1,1]:.2f}x_1 + {M[1,2]/M[1,1]:.2f}$'
    )
 
    A = M[:, 0:-1]
    b = M[:, -1:].flatten()
    d = np.linalg.det(A)
 
    if d != 0:
        solution = np.linalg.solve(A, b)
 
        ax.plot(
            solution[0],
            solution[1],
            'o',
            c='none',
            markersize=10,
            markeredgecolor='#00ff00',
            markeredgewidth=2
        )
 
        ax.text(
            solution[0] - 0.25,
            solution[1] + 0.75,
            f'${solution[0]:.2f},{solution[1]:.2f}$'
        )
 
    ax.tick_params(axis='x', labelsize=14)
    ax.tick_params(axis='y', labelsize=14)
 
    ax.set_xticks(np.arange(-10, 10))
    ax.set_yticks(np.arange(-10, 10))
 
    plt.xlabel('$x_1$', size=14)
    plt.ylabel('$x_2$', size=14)
 
    plt.legend(loc='upper right', fontsize=14)
    plt.axis([-10, 10, -10, 10])
 
    plt.grid()
    plt.gca().set_aspect('equal')
    plt.show()
 
 
# Example matrix (replace with your own system)

A_system = np.array([
    [-1, 3, 7],
    [3, -9, -21]

 ])
 
plot_lines(A_system)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[12], line 75
#      71     [3, -9, -21]
#      72
#      73  ])
#      74
# ---> 75 plot_lines(A_system)
#
# Cell In[12], line 32, in plot_lines(M)
#      28     b = M[:, -1:].flatten()
#      29     d = np.linalg.det(A)
#      30
#      31     if d != 0:
# ---> 32         solution = np.linalg.solve(A, b)
#      33
#      34         ax.plot(
#      35             solution[0],
#
# File ~/python/.venv/lib/python3.14/site-packages/numpy/linalg/_linalg.py:451, in solve(a, b)
#     448 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     449 with errstate(call=_raise_linalgerror_singular, invalid='call',
#     450               over='ignore', divide='ignore', under='ignore'):
# --> 451     r = gufunc(a, b, signature=signature)
#     453 return wrap(r.astype(result_t, copy=False))
#
# File ~/python/.venv/lib/python3.14/site-packages/numpy/linalg/_linalg.py:144, in _raise_linalgerror_singular(err, flag)
#     143 def _raise_linalgerror_singular(err, flag):
# --> 144     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix

# %%
A_system
# Out:
# array([[ -1,   3,   7],
#        [  3,  -9, -21]])

# %%
np.hstack(A_system.reshape(2,1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 np.hstack(A_system.reshape(2,1))
#
# ValueError: cannot reshape array of size 6 into shape (2,1)
